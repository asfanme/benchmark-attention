# %%
# CELL 1: SETUP & IMPORTS
import os
import time
import json
import torch
import torch.nn as nn
import torch.optim as optim
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
from torchvision.models import convnext_tiny, ConvNeXt_Tiny_Weights
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# Buat folder untuk menyimpan semua hasil agar tidak berantakan
SAVE_DIR = "results_exp1"
os.makedirs(SAVE_DIR, exist_ok=True)

# Cek ketersediaan GPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Menggunakan device: {device}")
if torch.cuda.is_available():
    print(f"Nama GPU: {torch.cuda.get_device_name(0)}")
# Out:
# Menggunakan device: cuda
# Nama GPU: NVIDIA GeForce RTX 5070

# %%
# CELL 2: FOCAL LOSS
class FocalLoss(nn.Module):
    def __init__(self, alpha=1, gamma=2, reduction='mean'):
        super(FocalLoss, self).__init__()
        self.alpha = alpha
        self.gamma = gamma
        self.reduction = reduction
        self.ce_loss = nn.CrossEntropyLoss(reduction='none')

    def forward(self, inputs, targets):
        ce_loss = self.ce_loss(inputs, targets)
        pt = torch.exp(-ce_loss)
        focal_loss = self.alpha * (1 - pt) ** self.gamma * ce_loss
        
        if self.reduction == 'mean':
            return focal_loss.mean()
        elif self.reduction == 'sum':
            return focal_loss.sum()
        else:
            return focal_loss

# %%
# CELL 3: DATASET & STRATIFIED K-FOLD (UPDATED LOCAL PATHS)
import os
import pandas as pd
from PIL import Image
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
from sklearn.model_selection import StratifiedKFold

# 1. Kunci Lokasi Data Lokal
data_dir = r"C:\Users\asfan\Data\ham10000\full"
csv_path = r"C:\Users\asfan\Data\ham10000\HAM10000_metadata.csv"

# 2. Baca Metadata dan Petakan Kelas
df = pd.read_csv(csv_path)
class_names = ["akiec", "bcc", "bkl", "df", "mel", "nv", "vasc"]
class_to_idx = {c: i for i, c in enumerate(class_names)}

# Mapping kelas teks ('dx') menjadi indeks angka
df['label'] = df['dx'].map(class_to_idx)

# Membangun full path untuk setiap gambar secara otomatis
# Asumsi format gambar adalah .jpg dan nama file sama dengan image_id
df['image_path'] = df.apply(lambda row: os.path.join(data_dir, row['dx'], f"{row['image_id']}.jpg"), axis=1)

# Verifikasi path (Cek apakah gambar pertama benar-benar ada)
print(f"Total data: {len(df)}")
print(f"Contoh path gambar: {df.iloc[0]['image_path']}")
if not os.path.exists(df.iloc[0]['image_path']):
    print("WARNING: Path gambar tidak ditemukan! Pastikan ekstensi .jpg atau nama folder sesuai.")

# 3. Class Dataset Kustom
class HAM10000Dataset(Dataset):
    def __init__(self, dataframe, transform=None):
        self.dataframe = dataframe.reset_index(drop=True)
        self.transform = transform

    def __len__(self):
        return len(self.dataframe)

    def __getitem__(self, idx):
        img_path = self.dataframe.iloc[idx]['image_path']
        label = self.dataframe.iloc[idx]['label']
        
        image = Image.open(img_path).convert('RGB')
        
        if self.transform:
            image = self.transform(image)
            
        return image, label

# 4. Augmentasi Data
train_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomVerticalFlip(),
    transforms.RandomRotation(20),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

val_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# 5. Persiapan Stratified 5-Fold
X = df['image_path'].values
y = df['label'].values
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

print("Dataset dan Stratified K-Fold siap!")
# Out:
# Total data: 10015
# Contoh path gambar: C:\Users\asfan\Data\ham10000\full\bkl\ISIC_0027419.jpg
# Dataset dan Stratified K-Fold siap!

# %%
# CELL 4: MODEL ARCHITECTURE (ConvNeXt + SE Attention) [REVISI DIMENSI]
class SEBlock(nn.Module):
    def __init__(self, channel, reduction=16):
        super(SEBlock, self).__init__()
        self.avg_pool = nn.AdaptiveAvgPool2d(1)
        self.fc = nn.Sequential(
            nn.Linear(channel, channel // reduction, bias=False),
            nn.ReLU(inplace=True),
            nn.Linear(channel // reduction, channel, bias=False),
            nn.Sigmoid()
        )

    def forward(self, x):
        b, c, _, _ = x.size()
        y = self.avg_pool(x).view(b, c)
        y = self.fc(y).view(b, c, 1, 1)
        return x * y.expand_as(x)

class ConvNeXt_SE_Attention(nn.Module):
    def __init__(self, num_classes=7):
        super(ConvNeXt_SE_Attention, self).__init__()
        # Load pre-trained ConvNeXt-Tiny
        convnext = convnext_tiny(weights=ConvNeXt_Tiny_Weights.DEFAULT)
        
        # Ekstrak feature extractor
        self.features = convnext.features
        
        # Dimensi output terakhir dari ConvNeXt-Tiny adalah 768
        self.se_block = SEBlock(channel=768)
        
        self.avgpool = nn.AdaptiveAvgPool2d(1)
        
        # REVISI DI SINI: Flatten diletakkan sebelum LayerNorm
        self.classifier = nn.Sequential(
            nn.Flatten(1),                     # Ubah dari (32, 768, 1, 1) menjadi (32, 768)
            nn.LayerNorm(768, eps=1e-6),       # Sekarang LayerNorm menerima bentuk yang benar
            nn.Linear(768, num_classes)
        )

    def forward(self, x):
        x = self.features(x)
        x = self.se_block(x) 
        x = self.avgpool(x)
        x = self.classifier(x)
        return x

# Test inisialisasi model
model_test = ConvNeXt_SE_Attention().to(device)
print(f"Total parameter: {sum(p.numel() for p in model_test.parameters())}")
# Out:
# Total parameter: 27899239

# %%
# CELL 5: TRAINING ENGINE WITH METRIC TRACKING
def train_model(fold, model, train_loader, val_loader, criterion, optimizer, num_epochs=50):
    best_val_loss = float('inf')
    history = {'train_loss': [], 'val_loss': [], 'train_acc': [], 'val_acc': []}
    
    start_time = time.time()
    torch.cuda.reset_peak_memory_stats()
    
    for epoch in range(num_epochs):
        # --- TRAINING PHASE ---
        model.train()
        running_loss, correct, total = 0.0, 0, 0
        
        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()
            
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            
            running_loss += loss.item() * inputs.size(0)
            _, preds = torch.max(outputs, 1)
            correct += torch.sum(preds == labels.data)
            total += labels.size(0)
            
        epoch_train_loss = running_loss / total
        epoch_train_acc = correct.double() / total
        
        # --- VALIDATION PHASE ---
        model.eval()
        val_loss, val_correct, val_total = 0.0, 0, 0
        
        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                
                val_loss += loss.item() * inputs.size(0)
                _, preds = torch.max(outputs, 1)
                val_correct += torch.sum(preds == labels.data)
                val_total += labels.size(0)
                
        epoch_val_loss = val_loss / val_total
        epoch_val_acc = val_correct.double() / val_total
        
        # Simpan metrik
        history['train_loss'].append(epoch_train_loss)
        history['val_loss'].append(epoch_val_loss)
        history['train_acc'].append(epoch_train_acc.item())
        history['val_acc'].append(epoch_val_acc.item())
        
        print(f"Epoch {epoch+1}/{num_epochs} - Train Loss: {epoch_train_loss:.4f} Acc: {epoch_train_acc:.4f} | Val Loss: {epoch_val_loss:.4f} Acc: {epoch_val_acc:.4f}")
        
        # Simpan model terbaik (.pth)
        if epoch_val_loss < best_val_loss:
            best_val_loss = epoch_val_loss
            model_save_path = os.path.join(SAVE_DIR, f"exp1_fold{fold}_best_model.pth")
            torch.save(model.state_dict(), model_save_path)
            
    # Kalkulasi performa hardware
    end_time = time.time()
    training_time = end_time - start_time
    max_memory = torch.cuda.max_memory_allocated() / (1024 ** 2) # Dalam MB
    
    # Simpan history ke JSON
    with open(os.path.join(SAVE_DIR, f"exp1_fold{fold}_history.json"), 'w') as f:
        json.dump(history, f)
        
    return history, training_time, max_memory

# %%
# CELL 6: EVALUATION & REPORTING
def evaluate_and_plot(fold, model, val_loader, history, training_time, max_memory, class_names):
    # Load model terbaik
    model.load_state_dict(torch.load(os.path.join(SAVE_DIR, f"exp1_fold{fold}_best_model.pth")))
    model.eval()
    
    all_preds, all_labels = [], []
    with torch.no_grad():
        for inputs, labels in val_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
            
    # 1. Classification Report & Metrics
    report = classification_report(all_labels, all_preds, target_names=class_names, output_dict=True)
    report_df = pd.DataFrame(report).transpose()
    report_df.to_csv(os.path.join(SAVE_DIR, f"exp1_fold{fold}_classification_report.csv"))
    
    # Simpan resource metrik
    resource_log = {
        'training_time_seconds': training_time,
        'max_gpu_memory_mb': max_memory,
        'overall_accuracy': accuracy_score(all_labels, all_preds)
    }
    with open(os.path.join(SAVE_DIR, f"exp1_fold{fold}_resources.json"), 'w') as f:
        json.dump(resource_log, f)
        
    # 2. Plot Loss & Accuracy Curves
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))
    ax1.plot(history['train_loss'], label='Train Loss')
    ax1.plot(history['val_loss'], label='Val Loss')
    ax1.set_title(f'Loss Curve - Fold {fold}')
    ax1.legend()
    
    ax2.plot(history['train_acc'], label='Train Acc')
    ax2.plot(history['val_acc'], label='Val Acc')
    ax2.set_title(f'Accuracy Curve - Fold {fold}')
    ax2.legend()
    plt.savefig(os.path.join(SAVE_DIR, f"exp1_fold{fold}_learning_curves.png"))
    plt.show()
    
    # 3. Plot Confusion Matrix
    cm = confusion_matrix(all_labels, all_preds)
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
    plt.title(f'Confusion Matrix - Fold {fold}')
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    plt.savefig(os.path.join(SAVE_DIR, f"exp1_fold{fold}_confusion_matrix.png"))
    plt.show()
    
    print(f"Semua log dan grafik untuk Fold {fold} berhasil disimpan di folder: {SAVE_DIR}")

# CONTOH EKSEKUSI (Bisa diletakkan di dalam loop Stratified K-Fold)
# class_names = ['AKIEC', 'BCC', 'BKL', 'DF', 'MEL', 'NV', 'VASC']
# criterion = FocalLoss(gamma=2)
# optimizer = optim.Adam(model.parameters(), lr=1e-4)
# history, t_time, max_mem = train_model(fold=1, model=model, train_loader=train_loader, val_loader=val_loader, criterion=criterion, optimizer=optimizer)
# evaluate_and_plot(fold=1, model=model, val_loader=val_loader, history=history, training_time=t_time, max_memory=max_mem, class_names=class_names)

# %%
# CELL 7: MASTER EXECUTION LOOP (RUN EXPERIMENT 1)
import torch.optim as optim

# Hyperparameters
BATCH_SIZE = 64
NUM_EPOCHS = 50
LEARNING_RATE = 1e-4

print(f"Mulai Eksperimen 1: ConvNeXt + SE Attention + Focal Loss")
print(f"Menyimpan di folder: {SAVE_DIR}\n" + "="*50)

for fold, (train_idx, val_idx) in enumerate(skf.split(X, y), 1):
    print(f"\n---> Memulai Fold {fold} <---")
    
    # Bagi dataframe berdasarkan index fold
    train_df = df.iloc[train_idx]
    val_df = df.iloc[val_idx]
    
    # Buat Dataset dan DataLoader
    train_dataset = HAM10000Dataset(train_df, transform=train_transform)
    val_dataset = HAM10000Dataset(val_df, transform=val_transform)
    
    # Gunakan num_workers=4 atau 8 jika CPU Xeon Anda mendukung untuk mempercepat I/O
    train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=0)
    val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=0)
    
    # Inisialisasi Ulang Model dan Optimizer untuk setiap Fold
    model = ConvNeXt_SE_Attention(num_classes=7).to(device)
    criterion = FocalLoss(gamma=2) # Mengatasi Imbalance
    optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE)
    
    # Mulai Training
    history, t_time, max_mem = train_model(
        fold=fold, 
        model=model, 
        train_loader=train_loader, 
        val_loader=val_loader, 
        criterion=criterion, 
        optimizer=optimizer, 
        num_epochs=NUM_EPOCHS
    )
    
    # Mulai Evaluasi & Plotting
    evaluate_and_plot(
        fold=fold, 
        model=model, 
        val_loader=val_loader, 
        history=history, 
        training_time=t_time, 
        max_memory=max_mem, 
        class_names=class_names
    )
    
print("\n" + "="*50)
print("ALHAMDULILLAH, EKSPERIMEN 2 SELESAI TOTAL!")
print("Semua grafik, metric, dan file .pth telah diamankan.")
# Out:
# Mulai Eksperimen 1: ConvNeXt + SE Attention + Focal Loss
# Menyimpan di folder: results_exp1
# ==================================================
#
# ---> Memulai Fold 1 <---
# Epoch 1/50 - Train Loss: 0.3912 Acc: 0.7542 | Val Loss: 0.2280 Acc: 0.8308
# Epoch 2/50 - Train Loss: 0.2078 Acc: 0.8371 | Val Loss: 0.1890 Acc: 0.8442
# Epoch 3/50 - Train Loss: 0.1409 Acc: 0.8773 | Val Loss: 0.1607 Acc: 0.8642
# Epoch 4/50 - Train Loss: 0.0977 Acc: 0.9101 | Val Loss: 0.1708 Acc: 0.8652
# Epoch 5/50 - Train Loss: 0.0757 Acc: 0.9281 | Val Loss: 0.1707 Acc: 0.8642
# Epoch 6/50 - Train Loss: 0.0524 Acc: 0.9476 | Val Loss: 0.1445 Acc: 0.8947
# Epoch 7/50 - Train Loss: 0.0427 Acc: 0.9529 | Val Loss: 0.1486 Acc: 0.8912
# Epoch 8/50 - Train Loss: 0.0399 Acc: 0.9576 | Val Loss: 0.1463 Acc: 0.8977
# Epoch 9/50 - Train Loss: 0.0285 Acc: 0.9723 | Val Loss: 0.1338 Acc: 0.8952
# Epoch 10/50 - Train Loss: 0.0252 Acc: 0.9718 | Val Loss: 0.1282 Acc: 0.8987
# Epoch 11/50 - Train Loss: 0.0223 Acc: 0.9767 | Val Loss: 0.1462 Acc: 0.9041
# Epoch 12/50 - Train Loss: 0.0196 Acc: 0.9803 | Val Loss: 0.1498 Acc: 0.8992
# Epoch 13/50 - Train Loss: 0.0185 Acc: 0.9809 | Val Loss: 0.1509 Acc: 0.9011
# Epoch 14/50 - Train Loss: 0.0143 Acc: 0.9853 | Val Loss: 0.1490 Acc: 0.9041
# Epoch 15/50 - Train Loss: 0.0149 Acc: 0.9853 | Val Loss: 0.1553 Acc: 0.9051
# Epoch 16/50 - Train Loss: 0.0130 Acc: 0.9864 | Val Loss: 0.2411 Acc: 0.8842
# Epoch 17/50 - Train Loss: 0.0148 Acc: 0.9846 | Val Loss: 0.1622 Acc: 0.9086
# Epoch 18/50 - Train Loss: 0.0169 Acc: 0.9825 | Val Loss: 0.2207 Acc: 0.8772
# Epoch 19/50 - Train Loss: 0.0115 Acc: 0.9870 | Val Loss: 0.1788 Acc: 0.8982
# Epoch 20/50 - Train Loss: 0.0109 Acc: 0.9888 | Val Loss: 0.1700 Acc: 0.9016
# Epoch 21/50 - Train Loss: 0.0171 Acc: 0.9825 | Val Loss: 0.1821 Acc: 0.8937
# Epoch 22/50 - Train Loss: 0.0157 Acc: 0.9843 | Val Loss: 0.1781 Acc: 0.8977
# Epoch 23/50 - Train Loss: 0.0111 Acc: 0.9883 | Val Loss: 0.1887 Acc: 0.8957
# Epoch 24/50 - Train Loss: 0.0127 Acc: 0.9865 | Val Loss: 0.1848 Acc: 0.9116
# Epoch 25/50 - Train Loss: 0.0065 Acc: 0.9943 | Val Loss: 0.1676 Acc: 0.9131
# Epoch 26/50 - Train Loss: 0.0109 Acc: 0.9885 | Val Loss: 0.1698 Acc: 0.9031
# Epoch 27/50 - Train Loss: 0.0162 Acc: 0.9839 | Val Loss: 0.1872 Acc: 0.9006
# Epoch 28/50 - Train Loss: 0.0101 Acc: 0.9895 | Val Loss: 0.1728 Acc: 0.9106
# Epoch 29/50 - Train Loss: 0.0095 Acc: 0.9921 | Val Loss: 0.1728 Acc: 0.9061
# Epoch 30/50 - Train Loss: 0.0094 Acc: 0.9916 | Val Loss: 0.1842 Acc: 0.9036
# Epoch 31/50 - Train Loss: 0.0115 Acc: 0.9899 | Val Loss: 0.1855 Acc: 0.9091
# Epoch 32/50 - Train Loss: 0.0079 Acc: 0.9929 | Val Loss: 0.1897 Acc: 0.9006
# Epoch 33/50 - Train Loss: 0.0065 Acc: 0.9926 | Val Loss: 0.1564 Acc: 0.9001
# Epoch 34/50 - Train Loss: 0.0061 Acc: 0.9933 | Val Loss: 0.1609 Acc: 0.9131
# Epoch 35/50 - Train Loss: 0.0069 Acc: 0.9923 | Val Loss: 0.1813 Acc: 0.9111
# Epoch 36/50 - Train Loss: 0.0053 Acc: 0.9943 | Val Loss: 0.1669 Acc: 0.9061
# Epoch 37/50 - Train Loss: 0.0164 Acc: 0.9836 | Val Loss: 0.2202 Acc: 0.8812
# Epoch 38/50 - Train Loss: 0.0149 Acc: 0.9859 | Val Loss: 0.1747 Acc: 0.9066
# Epoch 39/50 - Train Loss: 0.0088 Acc: 0.9913 | Val Loss: 0.1638 Acc: 0.9156
# Epoch 40/50 - Train Loss: 0.0046 Acc: 0.9954 | Val Loss: 0.1662 Acc: 0.9151
# Epoch 41/50 - Train Loss: 0.0076 Acc: 0.9916 | Val Loss: 0.1795 Acc: 0.9026
# Epoch 42/50 - Train Loss: 0.0103 Acc: 0.9898 | Val Loss: 0.1819 Acc: 0.9056
# Epoch 43/50 - Train Loss: 0.0080 Acc: 0.9924 | Val Loss: 0.1650 Acc: 0.9106
# Epoch 44/50 - Train Loss: 0.0080 Acc: 0.9926 | Val Loss: 0.1963 Acc: 0.9021
# Epoch 45/50 - Train Loss: 0.0060 Acc: 0.9939 | Val Loss: 0.2213 Acc: 0.9001
# Epoch 46/50 - Train Loss: 0.0083 Acc: 0.9919 | Val Loss: 0.1997 Acc: 0.9056
# Epoch 47/50 - Train Loss: 0.0033 Acc: 0.9961 | Val Loss: 0.1829 Acc: 0.9101
# Epoch 48/50 - Train Loss: 0.0028 Acc: 0.9964 | Val Loss: 0.1954 Acc: 0.9116
# Epoch 49/50 - Train Loss: 0.0072 Acc: 0.9925 | Val Loss: 0.1708 Acc: 0.9051
# Epoch 50/50 - Train Loss: 0.0058 Acc: 0.9941 | Val Loss: 0.1757 Acc: 0.9031
# Semua log dan grafik untuk Fold 1 berhasil disimpan di folder: results_exp1
#
# ---> Memulai Fold 2 <---
# Epoch 1/50 - Train Loss: 0.3819 Acc: 0.7552 | Val Loss: 0.2162 Acc: 0.8397
# Epoch 2/50 - Train Loss: 0.1962 Acc: 0.8449 | Val Loss: 0.2019 Acc: 0.8532
# Epoch 3/50 - Train Loss: 0.1393 Acc: 0.8786 | Val Loss: 0.1943 Acc: 0.8572
# Epoch 4/50 - Train Loss: 0.1004 Acc: 0.9080 | Val Loss: 0.1479 Acc: 0.8802
# Epoch 5/50 - Train Loss: 0.0775 Acc: 0.9269 | Val Loss: 0.1457 Acc: 0.8827
# Epoch 6/50 - Train Loss: 0.0605 Acc: 0.9363 | Val Loss: 0.1463 Acc: 0.8822
# Epoch 7/50 - Train Loss: 0.0483 Acc: 0.9471 | Val Loss: 0.1502 Acc: 0.8907
# Epoch 8/50 - Train Loss: 0.0381 Acc: 0.9627 | Val Loss: 0.1646 Acc: 0.8832
# Epoch 9/50 - Train Loss: 0.0274 Acc: 0.9698 | Val Loss: 0.1905 Acc: 0.8827
# Epoch 10/50 - Train Loss: 0.0352 Acc: 0.9649 | Val Loss: 0.1311 Acc: 0.9091
# Epoch 11/50 - Train Loss: 0.0249 Acc: 0.9759 | Val Loss: 0.2226 Acc: 0.8772
# Epoch 12/50 - Train Loss: 0.0299 Acc: 0.9689 | Val Loss: 0.1363 Acc: 0.9041
# Epoch 13/50 - Train Loss: 0.0172 Acc: 0.9812 | Val Loss: 0.1417 Acc: 0.9111
# Epoch 14/50 - Train Loss: 0.0185 Acc: 0.9792 | Val Loss: 0.1476 Acc: 0.9066
# Epoch 15/50 - Train Loss: 0.0120 Acc: 0.9883 | Val Loss: 0.1368 Acc: 0.9101
# Epoch 16/50 - Train Loss: 0.0155 Acc: 0.9828 | Val Loss: 0.1546 Acc: 0.9101
# Epoch 17/50 - Train Loss: 0.0132 Acc: 0.9873 | Val Loss: 0.1581 Acc: 0.9116
# Epoch 18/50 - Train Loss: 0.0106 Acc: 0.9885 | Val Loss: 0.1976 Acc: 0.9041
# Epoch 19/50 - Train Loss: 0.0139 Acc: 0.9846 | Val Loss: 0.1532 Acc: 0.9156
# Epoch 20/50 - Train Loss: 0.0229 Acc: 0.9760 | Val Loss: 0.1891 Acc: 0.8972
# Epoch 21/50 - Train Loss: 0.0187 Acc: 0.9807 | Val Loss: 0.1676 Acc: 0.9111
# Epoch 22/50 - Train Loss: 0.0083 Acc: 0.9913 | Val Loss: 0.1669 Acc: 0.9156
# Epoch 23/50 - Train Loss: 0.0083 Acc: 0.9896 | Val Loss: 0.1664 Acc: 0.9116
# Epoch 24/50 - Train Loss: 0.0148 Acc: 0.9844 | Val Loss: 0.1584 Acc: 0.9121
# Epoch 25/50 - Train Loss: 0.0120 Acc: 0.9873 | Val Loss: 0.1867 Acc: 0.9031
# Epoch 26/50 - Train Loss: 0.0153 Acc: 0.9830 | Val Loss: 0.1773 Acc: 0.8997
# Epoch 27/50 - Train Loss: 0.0134 Acc: 0.9859 | Val Loss: 0.1686 Acc: 0.9116
# Epoch 28/50 - Train Loss: 0.0079 Acc: 0.9929 | Val Loss: 0.1826 Acc: 0.9111
# Epoch 29/50 - Train Loss: 0.0084 Acc: 0.9920 | Val Loss: 0.2221 Acc: 0.8972
# Epoch 30/50 - Train Loss: 0.0082 Acc: 0.9921 | Val Loss: 0.1934 Acc: 0.9011
# Epoch 31/50 - Train Loss: 0.0121 Acc: 0.9873 | Val Loss: 0.1745 Acc: 0.9096
# Epoch 32/50 - Train Loss: 0.0084 Acc: 0.9915 | Val Loss: 0.1666 Acc: 0.9186
# Epoch 33/50 - Train Loss: 0.0057 Acc: 0.9936 | Val Loss: 0.1838 Acc: 0.9126
# Epoch 34/50 - Train Loss: 0.0086 Acc: 0.9916 | Val Loss: 0.1923 Acc: 0.9121
# Epoch 35/50 - Train Loss: 0.0092 Acc: 0.9880 | Val Loss: 0.1619 Acc: 0.9201
# Epoch 36/50 - Train Loss: 0.0158 Acc: 0.9848 | Val Loss: 0.1683 Acc: 0.9116
# Epoch 37/50 - Train Loss: 0.0105 Acc: 0.9904 | Val Loss: 0.1573 Acc: 0.9176
# Epoch 38/50 - Train Loss: 0.0180 Acc: 0.9815 | Val Loss: 0.1588 Acc: 0.9146
# Epoch 39/50 - Train Loss: 0.0077 Acc: 0.9910 | Val Loss: 0.1739 Acc: 0.9151
# Epoch 40/50 - Train Loss: 0.0048 Acc: 0.9948 | Val Loss: 0.1740 Acc: 0.9201
# Epoch 41/50 - Train Loss: 0.0046 Acc: 0.9934 | Val Loss: 0.1654 Acc: 0.9151
# Epoch 42/50 - Train Loss: 0.0076 Acc: 0.9935 | Val Loss: 0.1799 Acc: 0.9086
# Epoch 43/50 - Train Loss: 0.0096 Acc: 0.9920 | Val Loss: 0.2128 Acc: 0.9041
# Epoch 44/50 - Train Loss: 0.0085 Acc: 0.9928 | Val Loss: 0.2289 Acc: 0.8977
# Epoch 45/50 - Train Loss: 0.0232 Acc: 0.9783 | Val Loss: 0.1770 Acc: 0.9116
# Epoch 46/50 - Train Loss: 0.0101 Acc: 0.9888 | Val Loss: 0.1998 Acc: 0.9106
# Epoch 47/50 - Train Loss: 0.0055 Acc: 0.9951 | Val Loss: 0.1720 Acc: 0.9201
# Epoch 48/50 - Train Loss: 0.0044 Acc: 0.9960 | Val Loss: 0.2075 Acc: 0.9121
# Epoch 49/50 - Train Loss: 0.0035 Acc: 0.9966 | Val Loss: 0.1882 Acc: 0.9146
# Epoch 50/50 - Train Loss: 0.0069 Acc: 0.9935 | Val Loss: 0.2020 Acc: 0.9156
# Semua log dan grafik untuk Fold 2 berhasil disimpan di folder: results_exp1
#
# ---> Memulai Fold 3 <---
# Epoch 1/50 - Train Loss: 0.3815 Acc: 0.7556 | Val Loss: 0.3041 Acc: 0.7858
# Epoch 2/50 - Train Loss: 0.2123 Acc: 0.8359 | Val Loss: 0.2194 Acc: 0.8323
# Epoch 3/50 - Train Loss: 0.1486 Acc: 0.8791 | Val Loss: 0.1759 Acc: 0.8572
# Epoch 4/50 - Train Loss: 0.1122 Acc: 0.8993 | Val Loss: 0.1655 Acc: 0.8557
# Epoch 5/50 - Train Loss: 0.0818 Acc: 0.9210 | Val Loss: 0.1453 Acc: 0.8897
# Epoch 6/50 - Train Loss: 0.0563 Acc: 0.9411 | Val Loss: 0.1410 Acc: 0.8872
# Epoch 7/50 - Train Loss: 0.0402 Acc: 0.9588 | Val Loss: 0.1682 Acc: 0.8827
# Epoch 8/50 - Train Loss: 0.0426 Acc: 0.9561 | Val Loss: 0.1489 Acc: 0.8922
# Epoch 9/50 - Train Loss: 0.0296 Acc: 0.9698 | Val Loss: 0.1823 Acc: 0.8707
# Epoch 10/50 - Train Loss: 0.0302 Acc: 0.9697 | Val Loss: 0.1432 Acc: 0.8957
# Epoch 11/50 - Train Loss: 0.0308 Acc: 0.9678 | Val Loss: 0.1965 Acc: 0.8867
# Epoch 12/50 - Train Loss: 0.0199 Acc: 0.9802 | Val Loss: 0.1702 Acc: 0.8917
# Epoch 13/50 - Train Loss: 0.0145 Acc: 0.9840 | Val Loss: 0.1513 Acc: 0.9066
# Epoch 14/50 - Train Loss: 0.0149 Acc: 0.9841 | Val Loss: 0.1930 Acc: 0.8907
# Epoch 15/50 - Train Loss: 0.0207 Acc: 0.9789 | Val Loss: 0.1749 Acc: 0.8837
# Epoch 16/50 - Train Loss: 0.0185 Acc: 0.9822 | Val Loss: 0.1820 Acc: 0.8887
# Epoch 17/50 - Train Loss: 0.0220 Acc: 0.9780 | Val Loss: 0.1695 Acc: 0.8947
# Epoch 18/50 - Train Loss: 0.0109 Acc: 0.9909 | Val Loss: 0.1763 Acc: 0.9076
# Epoch 19/50 - Train Loss: 0.0103 Acc: 0.9890 | Val Loss: 0.1844 Acc: 0.8892
# Epoch 20/50 - Train Loss: 0.0168 Acc: 0.9814 | Val Loss: 0.2152 Acc: 0.8822
# Epoch 21/50 - Train Loss: 0.0157 Acc: 0.9851 | Val Loss: 0.1793 Acc: 0.8947
# Epoch 22/50 - Train Loss: 0.0102 Acc: 0.9898 | Val Loss: 0.1865 Acc: 0.8967
# Epoch 23/50 - Train Loss: 0.0131 Acc: 0.9868 | Val Loss: 0.2171 Acc: 0.8917
# Epoch 24/50 - Train Loss: 0.0129 Acc: 0.9849 | Val Loss: 0.1817 Acc: 0.9096
# Epoch 25/50 - Train Loss: 0.0062 Acc: 0.9924 | Val Loss: 0.2064 Acc: 0.8992
# Epoch 26/50 - Train Loss: 0.0124 Acc: 0.9879 | Val Loss: 0.1883 Acc: 0.9026
# Epoch 27/50 - Train Loss: 0.0110 Acc: 0.9886 | Val Loss: 0.1931 Acc: 0.9036
# Epoch 28/50 - Train Loss: 0.0107 Acc: 0.9889 | Val Loss: 0.1995 Acc: 0.8812
# Epoch 29/50 - Train Loss: 0.0124 Acc: 0.9873 | Val Loss: 0.2359 Acc: 0.8932
# Epoch 30/50 - Train Loss: 0.0110 Acc: 0.9890 | Val Loss: 0.1758 Acc: 0.9131
# Epoch 31/50 - Train Loss: 0.0124 Acc: 0.9889 | Val Loss: 0.1967 Acc: 0.8947
# Epoch 32/50 - Train Loss: 0.0135 Acc: 0.9876 | Val Loss: 0.1934 Acc: 0.8922
# Epoch 33/50 - Train Loss: 0.0143 Acc: 0.9865 | Val Loss: 0.1825 Acc: 0.9031
# Epoch 34/50 - Train Loss: 0.0071 Acc: 0.9915 | Val Loss: 0.1630 Acc: 0.9101
# Epoch 35/50 - Train Loss: 0.0226 Acc: 0.9779 | Val Loss: 0.1944 Acc: 0.9016
# Epoch 36/50 - Train Loss: 0.0086 Acc: 0.9911 | Val Loss: 0.1781 Acc: 0.9046
# Epoch 37/50 - Train Loss: 0.0030 Acc: 0.9965 | Val Loss: 0.1952 Acc: 0.9106
# Epoch 38/50 - Train Loss: 0.0028 Acc: 0.9973 | Val Loss: 0.1774 Acc: 0.9136
# Epoch 39/50 - Train Loss: 0.0080 Acc: 0.9928 | Val Loss: 0.2469 Acc: 0.8897
# Epoch 40/50 - Train Loss: 0.0084 Acc: 0.9914 | Val Loss: 0.1932 Acc: 0.9061
# Epoch 41/50 - Train Loss: 0.0057 Acc: 0.9938 | Val Loss: 0.1977 Acc: 0.8952
# Epoch 42/50 - Train Loss: 0.0150 Acc: 0.9833 | Val Loss: 0.2166 Acc: 0.8967
# Epoch 43/50 - Train Loss: 0.0112 Acc: 0.9900 | Val Loss: 0.2201 Acc: 0.9011
# Epoch 44/50 - Train Loss: 0.0179 Acc: 0.9815 | Val Loss: 0.2057 Acc: 0.9081
# Epoch 45/50 - Train Loss: 0.0035 Acc: 0.9966 | Val Loss: 0.2123 Acc: 0.8997
# Epoch 46/50 - Train Loss: 0.0045 Acc: 0.9953 | Val Loss: 0.2186 Acc: 0.9091
# Epoch 47/50 - Train Loss: 0.0088 Acc: 0.9913 | Val Loss: 0.2172 Acc: 0.8952
# Epoch 48/50 - Train Loss: 0.0050 Acc: 0.9950 | Val Loss: 0.2020 Acc: 0.9006
# Epoch 49/50 - Train Loss: 0.0051 Acc: 0.9956 | Val Loss: 0.2027 Acc: 0.9001
# Epoch 50/50 - Train Loss: 0.0032 Acc: 0.9966 | Val Loss: 0.2156 Acc: 0.9016
# Semua log dan grafik untuk Fold 3 berhasil disimpan di folder: results_exp1
#
# ---> Memulai Fold 4 <---
# Epoch 1/50 - Train Loss: 0.3860 Acc: 0.7499 | Val Loss: 0.2486 Acc: 0.8078
# Epoch 2/50 - Train Loss: 0.2022 Acc: 0.8395 | Val Loss: 0.2313 Acc: 0.8293
# Epoch 3/50 - Train Loss: 0.1422 Acc: 0.8794 | Val Loss: 0.1720 Acc: 0.8557
# Epoch 4/50 - Train Loss: 0.1083 Acc: 0.9020 | Val Loss: 0.1607 Acc: 0.8682
# Epoch 5/50 - Train Loss: 0.0878 Acc: 0.9130 | Val Loss: 0.1650 Acc: 0.8797
# Epoch 6/50 - Train Loss: 0.0617 Acc: 0.9393 | Val Loss: 0.1680 Acc: 0.8757
# Epoch 7/50 - Train Loss: 0.0469 Acc: 0.9492 | Val Loss: 0.1690 Acc: 0.8852
# Epoch 8/50 - Train Loss: 0.0426 Acc: 0.9556 | Val Loss: 0.1928 Acc: 0.8757
# Epoch 9/50 - Train Loss: 0.0329 Acc: 0.9634 | Val Loss: 0.1756 Acc: 0.8872
# Epoch 10/50 - Train Loss: 0.0273 Acc: 0.9695 | Val Loss: 0.1576 Acc: 0.8937
# Epoch 11/50 - Train Loss: 0.0242 Acc: 0.9734 | Val Loss: 0.1437 Acc: 0.9011
# Epoch 12/50 - Train Loss: 0.0198 Acc: 0.9779 | Val Loss: 0.1339 Acc: 0.9086
# Epoch 13/50 - Train Loss: 0.0148 Acc: 0.9834 | Val Loss: 0.1914 Acc: 0.8887
# Epoch 14/50 - Train Loss: 0.0158 Acc: 0.9829 | Val Loss: 0.1736 Acc: 0.9001
# Epoch 15/50 - Train Loss: 0.0266 Acc: 0.9722 | Val Loss: 0.1443 Acc: 0.9091
# Epoch 16/50 - Train Loss: 0.0204 Acc: 0.9799 | Val Loss: 0.2321 Acc: 0.8767
# Epoch 17/50 - Train Loss: 0.0200 Acc: 0.9795 | Val Loss: 0.1636 Acc: 0.9076
# Epoch 18/50 - Train Loss: 0.0131 Acc: 0.9873 | Val Loss: 0.1448 Acc: 0.9061
# Epoch 19/50 - Train Loss: 0.0130 Acc: 0.9861 | Val Loss: 0.1491 Acc: 0.9126
# Epoch 20/50 - Train Loss: 0.0079 Acc: 0.9913 | Val Loss: 0.1774 Acc: 0.9071
# Epoch 21/50 - Train Loss: 0.0100 Acc: 0.9901 | Val Loss: 0.1775 Acc: 0.9111
# Epoch 22/50 - Train Loss: 0.0178 Acc: 0.9818 | Val Loss: 0.1881 Acc: 0.8982
# Epoch 23/50 - Train Loss: 0.0151 Acc: 0.9827 | Val Loss: 0.2148 Acc: 0.8967
# Epoch 24/50 - Train Loss: 0.0194 Acc: 0.9800 | Val Loss: 0.2010 Acc: 0.9041
# Epoch 25/50 - Train Loss: 0.0248 Acc: 0.9754 | Val Loss: 0.1719 Acc: 0.9031
# Epoch 26/50 - Train Loss: 0.0105 Acc: 0.9901 | Val Loss: 0.1762 Acc: 0.9131
# Epoch 27/50 - Train Loss: 0.0060 Acc: 0.9938 | Val Loss: 0.1837 Acc: 0.9071
# Epoch 28/50 - Train Loss: 0.0129 Acc: 0.9876 | Val Loss: 0.2471 Acc: 0.8827
# Epoch 29/50 - Train Loss: 0.0085 Acc: 0.9915 | Val Loss: 0.1620 Acc: 0.9156
# Epoch 30/50 - Train Loss: 0.0092 Acc: 0.9896 | Val Loss: 0.1806 Acc: 0.9126
# Epoch 31/50 - Train Loss: 0.0084 Acc: 0.9908 | Val Loss: 0.1914 Acc: 0.9106
# Epoch 32/50 - Train Loss: 0.0095 Acc: 0.9903 | Val Loss: 0.1995 Acc: 0.9081
# Epoch 33/50 - Train Loss: 0.0272 Acc: 0.9733 | Val Loss: 0.1676 Acc: 0.8997
# Epoch 34/50 - Train Loss: 0.0143 Acc: 0.9846 | Val Loss: 0.1610 Acc: 0.9131
# Epoch 35/50 - Train Loss: 0.0065 Acc: 0.9940 | Val Loss: 0.1672 Acc: 0.9171
# Epoch 36/50 - Train Loss: 0.0103 Acc: 0.9903 | Val Loss: 0.2226 Acc: 0.8987
# Epoch 37/50 - Train Loss: 0.0076 Acc: 0.9906 | Val Loss: 0.2226 Acc: 0.8937
# Epoch 38/50 - Train Loss: 0.0043 Acc: 0.9959 | Val Loss: 0.2086 Acc: 0.9086
# Epoch 39/50 - Train Loss: 0.0058 Acc: 0.9939 | Val Loss: 0.1851 Acc: 0.9126
# Epoch 40/50 - Train Loss: 0.0057 Acc: 0.9939 | Val Loss: 0.2133 Acc: 0.9081
# Epoch 41/50 - Train Loss: 0.0046 Acc: 0.9944 | Val Loss: 0.2084 Acc: 0.9081
# Epoch 42/50 - Train Loss: 0.0141 Acc: 0.9839 | Val Loss: 0.1999 Acc: 0.9026
# Epoch 43/50 - Train Loss: 0.0124 Acc: 0.9888 | Val Loss: 0.1805 Acc: 0.9061
# Epoch 44/50 - Train Loss: 0.0079 Acc: 0.9923 | Val Loss: 0.2375 Acc: 0.9066
# Epoch 45/50 - Train Loss: 0.0134 Acc: 0.9860 | Val Loss: 0.1705 Acc: 0.9091
# Epoch 46/50 - Train Loss: 0.0048 Acc: 0.9955 | Val Loss: 0.1667 Acc: 0.9091
# Epoch 47/50 - Train Loss: 0.0073 Acc: 0.9928 | Val Loss: 0.1980 Acc: 0.9006
# Epoch 48/50 - Train Loss: 0.0109 Acc: 0.9895 | Val Loss: 0.1806 Acc: 0.9131
# Epoch 49/50 - Train Loss: 0.0053 Acc: 0.9944 | Val Loss: 0.1718 Acc: 0.9151
# Epoch 50/50 - Train Loss: 0.0069 Acc: 0.9939 | Val Loss: 0.1957 Acc: 0.9021
# Semua log dan grafik untuk Fold 4 berhasil disimpan di folder: results_exp1
#
# ---> Memulai Fold 5 <---
# Epoch 1/50 - Train Loss: 0.4013 Acc: 0.7541 | Val Loss: 0.2474 Acc: 0.8123
# Epoch 2/50 - Train Loss: 0.2137 Acc: 0.8377 | Val Loss: 0.2492 Acc: 0.8123
# Epoch 3/50 - Train Loss: 0.1516 Acc: 0.8697 | Val Loss: 0.1769 Acc: 0.8527
# Epoch 4/50 - Train Loss: 0.1054 Acc: 0.8972 | Val Loss: 0.1483 Acc: 0.8722
# Epoch 5/50 - Train Loss: 0.0749 Acc: 0.9269 | Val Loss: 0.1722 Acc: 0.8717
# Epoch 6/50 - Train Loss: 0.0609 Acc: 0.9368 | Val Loss: 0.1548 Acc: 0.8767
# Epoch 7/50 - Train Loss: 0.0429 Acc: 0.9542 | Val Loss: 0.1474 Acc: 0.8817
# Epoch 8/50 - Train Loss: 0.0381 Acc: 0.9578 | Val Loss: 0.1418 Acc: 0.8907
# Epoch 9/50 - Train Loss: 0.0288 Acc: 0.9712 | Val Loss: 0.2018 Acc: 0.8717
# Epoch 10/50 - Train Loss: 0.0250 Acc: 0.9720 | Val Loss: 0.1313 Acc: 0.9051
# Epoch 11/50 - Train Loss: 0.0181 Acc: 0.9790 | Val Loss: 0.1747 Acc: 0.8912
# Epoch 12/50 - Train Loss: 0.0175 Acc: 0.9805 | Val Loss: 0.1750 Acc: 0.8842
# Epoch 13/50 - Train Loss: 0.0204 Acc: 0.9757 | Val Loss: 0.1636 Acc: 0.8957
# Epoch 14/50 - Train Loss: 0.0161 Acc: 0.9844 | Val Loss: 0.1737 Acc: 0.8737
# Epoch 15/50 - Train Loss: 0.0166 Acc: 0.9815 | Val Loss: 0.1531 Acc: 0.9061
# Epoch 16/50 - Train Loss: 0.0250 Acc: 0.9762 | Val Loss: 0.1959 Acc: 0.9011
# Epoch 17/50 - Train Loss: 0.0205 Acc: 0.9778 | Val Loss: 0.1674 Acc: 0.8957
# Epoch 18/50 - Train Loss: 0.0099 Acc: 0.9888 | Val Loss: 0.1595 Acc: 0.9036
# Epoch 19/50 - Train Loss: 0.0093 Acc: 0.9910 | Val Loss: 0.1620 Acc: 0.9061
# Epoch 20/50 - Train Loss: 0.0134 Acc: 0.9866 | Val Loss: 0.1769 Acc: 0.9006
# Epoch 21/50 - Train Loss: 0.0146 Acc: 0.9864 | Val Loss: 0.1836 Acc: 0.8932
# Epoch 22/50 - Train Loss: 0.0104 Acc: 0.9894 | Val Loss: 0.2017 Acc: 0.8922
# Epoch 23/50 - Train Loss: 0.0105 Acc: 0.9891 | Val Loss: 0.1892 Acc: 0.8917
# Epoch 24/50 - Train Loss: 0.0148 Acc: 0.9861 | Val Loss: 0.1820 Acc: 0.9041
# Epoch 25/50 - Train Loss: 0.0210 Acc: 0.9799 | Val Loss: 0.1855 Acc: 0.9021
# Epoch 26/50 - Train Loss: 0.0169 Acc: 0.9841 | Val Loss: 0.2011 Acc: 0.8887
# Epoch 27/50 - Train Loss: 0.0090 Acc: 0.9901 | Val Loss: 0.1724 Acc: 0.9066
# Epoch 28/50 - Train Loss: 0.0063 Acc: 0.9934 | Val Loss: 0.2032 Acc: 0.9026
# Epoch 29/50 - Train Loss: 0.0067 Acc: 0.9929 | Val Loss: 0.2011 Acc: 0.8987
# Epoch 30/50 - Train Loss: 0.0071 Acc: 0.9936 | Val Loss: 0.1548 Acc: 0.9101
# Epoch 31/50 - Train Loss: 0.0102 Acc: 0.9903 | Val Loss: 0.1980 Acc: 0.8987
# Epoch 32/50 - Train Loss: 0.0149 Acc: 0.9855 | Val Loss: 0.1974 Acc: 0.8907
# Epoch 33/50 - Train Loss: 0.0112 Acc: 0.9894 | Val Loss: 0.2076 Acc: 0.8967
# Epoch 34/50 - Train Loss: 0.0095 Acc: 0.9901 | Val Loss: 0.2034 Acc: 0.9026
# Epoch 35/50 - Train Loss: 0.0063 Acc: 0.9934 | Val Loss: 0.2092 Acc: 0.8982
# Epoch 36/50 - Train Loss: 0.0068 Acc: 0.9933 | Val Loss: 0.2119 Acc: 0.9041
# Epoch 37/50 - Train Loss: 0.0037 Acc: 0.9968 | Val Loss: 0.2149 Acc: 0.8957
# Epoch 38/50 - Train Loss: 0.0078 Acc: 0.9911 | Val Loss: 0.2011 Acc: 0.8957
# Epoch 39/50 - Train Loss: 0.0102 Acc: 0.9904 | Val Loss: 0.2113 Acc: 0.9076
# Epoch 40/50 - Train Loss: 0.0064 Acc: 0.9924 | Val Loss: 0.1915 Acc: 0.9036
# Epoch 41/50 - Train Loss: 0.0111 Acc: 0.9901 | Val Loss: 0.1961 Acc: 0.8997
# Epoch 42/50 - Train Loss: 0.0066 Acc: 0.9926 | Val Loss: 0.1704 Acc: 0.9126
# Epoch 43/50 - Train Loss: 0.0077 Acc: 0.9913 | Val Loss: 0.2619 Acc: 0.8712
# Epoch 44/50 - Train Loss: 0.0059 Acc: 0.9941 | Val Loss: 0.2024 Acc: 0.9011
# Epoch 45/50 - Train Loss: 0.0058 Acc: 0.9935 | Val Loss: 0.2133 Acc: 0.8897
# Epoch 46/50 - Train Loss: 0.0098 Acc: 0.9903 | Val Loss: 0.2156 Acc: 0.8947
# Epoch 47/50 - Train Loss: 0.0111 Acc: 0.9889 | Val Loss: 0.1904 Acc: 0.8977
# Epoch 48/50 - Train Loss: 0.0094 Acc: 0.9910 | Val Loss: 0.1897 Acc: 0.9001
# Epoch 49/50 - Train Loss: 0.0064 Acc: 0.9931 | Val Loss: 0.2322 Acc: 0.8867
# Epoch 50/50 - Train Loss: 0.0108 Acc: 0.9890 | Val Loss: 0.2154 Acc: 0.8887
# Semua log dan grafik untuk Fold 5 berhasil disimpan di folder: results_exp1
#
# ==================================================
# ALHAMDULILLAH, EKSPERIMEN 2 SELESAI TOTAL!
# Semua grafik, metric, dan file .pth telah diamankan.

# %%
# CELL 8: SUMMARY CALCULATOR (MEAN & STD) - FIXED VERSION
import os
import pandas as pd
import glob

# Pastikan path folder benar sesuai hasil running tadi
results_path = "results_exp1"
csv_files = glob.glob(os.path.join(results_path, "exp1_fold*_classification_report.csv"))

if len(csv_files) < 5:
    print(f"Peringatan: Baru ditemukan {len(csv_files)} file CSV. Pastikan 5 fold sudah selesai running semua.")
else:
    all_reports = []
    
    for file in csv_files:
        # Perbaikan: index_col=0 digunakan agar kolom pertama (nama kelas) jadi index
        df_fold = pd.read_csv(file, index_col=0) 
        all_reports.append(df_fold)
    
    # Gabungkan semua fold
    full_concat = pd.concat(all_reports)
    
    # Hitung rata-rata (Mean) dan Standar Deviasi (Std)
    mean_report = full_concat.groupby(full_concat.index).mean()
    std_report = full_concat.groupby(full_concat.index).std()

    # Mengambil metrik utama (Accuracy dan Macro F1)
    # Note: Di report sklearn, accuracy biasanya ada di baris 'accuracy' kolom 'precision'
    mean_accuracy = mean_report.loc['accuracy', 'precision']
    mean_macro_f1 = mean_report.loc['macro avg', 'f1-score']
    
    std_accuracy = std_report.loc['accuracy', 'precision']
    std_macro_f1 = std_report.loc['macro avg', 'f1-score']
    
    print("="*50)
    print("   HASIL AKHIR EKSPERIMEN 1 (STATISTIK 5-FOLD)")
    print("="*50)
    print(f"Mean Accuracy : {mean_accuracy:.4f} ± {std_accuracy:.4f}")
    print(f"Mean Macro F1 : {mean_macro_f1:.4f} ± {std_macro_f1:.4f}")
    print("-" * 50)
    
    # Tampilkan tabel lengkap rata-rata per kelas agar bisa langsung di-copy ke Paper
    print("\nLaporan Lengkap (Mean Performance per Class):")
    target_rows = class_names + ['macro avg', 'weighted avg']
    summary_table = mean_report.loc[target_rows, ['precision', 'recall', 'f1-score']]
    
    # Menampilkan tabel
    from IPython.display import display
    display(summary_table)
    
    # Simpan hasil akhir ke CSV untuk arsip
    summary_table.to_csv(os.path.join(results_path, "EXP1_FINAL_SUMMARY_STATISTICS.csv"))
    print(f"\n[INFO] Laporan final telah disimpan di: {results_path}/EXP1_FINAL_SUMMARY_STATISTICS.csv")
# Out:
# ==================================================
#    HASIL AKHIR EKSPERIMEN 1 (STATISTIK 5-FOLD)
# ==================================================
# Mean Accuracy : 0.9017 ± 0.0092
# Mean Macro F1 : 0.8468 ± 0.0153
# --------------------------------------------------
#
# Laporan Lengkap (Mean Performance per Class):
#               precision    recall  f1-score
# akiec          0.784051  0.752168  0.767221
# bcc            0.879408  0.855930  0.867033
# bkl            0.842297  0.804375  0.822669
# df             0.891301  0.808696  0.843045
# mel            0.738246  0.762776  0.748718
# nv             0.946483  0.952722  0.949502
# vasc           0.937493  0.922414  0.929131
# macro avg      0.859897  0.837012  0.846760
# weighted avg   0.902401  0.901747  0.901581
# [INFO] Laporan final telah disimpan di: results_exp1/EXP1_FINAL_SUMMARY_STATISTICS.csv
